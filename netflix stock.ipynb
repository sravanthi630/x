# %% [markdown]
# # NETFLIX STOCK PREDICTION

# %%
import numpy as np
import pandas as pd

# %%
netflix = pd.read_csv('NFLX.csv')

# %%
netflix['Date'] = pd.to_datetime(netflix['Date'])
netflix['year'] = netflix['Date'].dt.year
netflix['month'] = netflix['Date'].dt.month
netflix['day'] = netflix['Date'].dt.day

# %% [markdown]
# # DISPALYING FIRST 10 ROWS

# %%
netflix.head(10)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1 2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2 2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3 2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4 2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# 5 2015-12-23  116.910004  118.559998  115.779999  118.160004  118.160004
# 6 2015-12-24  118.220001  118.800003  117.300003  117.330002  117.330002
# 7 2015-12-28  117.260002  117.349998  113.849998  117.110001  117.110001
# 8 2015-12-29  118.190002  119.599998  116.919998  119.120003  119.120003
# 9 2015-12-30  118.949997  119.019997  116.430000  116.709999  116.709999
#
#      Volume  year  month  day
# 0  13181000  2015     12   16
# 1  17284900  2015     12   17
# 2  17948100  2015     12   18
# 3  11670000  2015     12   21
# 4   9689000  2015     12   22
# 5   9324300  2015     12   23
# 6   3531300  2015     12   24
# 7   8424300  2015     12   28
# 8   8159200  2015     12   29
# 9   8149700  2015     12   30

# %% [markdown]
# # DISPALYING LATS 20 ROWS

# %%
netflix.tail(20)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 987  2019-11-18  296.000000  304.989990  293.279999  302.570007  302.570007
# 988  2019-11-19  304.010010  305.670013  298.519989  302.600006  302.600006
# 989  2019-11-20  301.010010  308.250000  301.000000  305.160004  305.160004
# 990  2019-11-21  306.000000  312.690002  304.260010  311.690002  311.690002
# 991  2019-11-22  309.100006  311.399994  304.410004  310.480011  310.480011
# 992  2019-11-25  308.829987  315.730011  305.250000  315.549988  315.549988
# 993  2019-11-26  315.000000  316.500000  311.690002  312.489990  312.489990
# 994  2019-11-27  313.929993  316.820007  312.750000  315.929993  315.929993
# 995  2019-11-29  315.779999  316.619995  313.339996  314.660004  314.660004
# 996  2019-12-02  314.390015  314.390015  303.750000  309.989990  309.989990
# 997  2019-12-03  302.220001  307.359985  301.880005  306.160004  306.160004
# 998  2019-12-04  308.429993  308.429993  303.269989  304.320007  304.320007
# 999  2019-12-05  305.269989  306.480011  298.809998  302.859985  302.859985
# 1000 2019-12-06  304.700012  307.850006  302.600006  307.350006  307.350006
# 1001 2019-12-09  307.350006  311.489990  302.440002  302.500000  302.500000
# 1002 2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 1003 2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 1004 2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 1005 2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 1006 2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#         Volume  year  month  day
# 987    8616600  2019     11   18
# 988    5918000  2019     11   19
# 989    5111800  2019     11   20
# 990    7488400  2019     11   21
# 991    5970100  2019     11   22
# 992    7873900  2019     11   25
# 993    5321000  2019     11   26
# 994    4096900  2019     11   27
# 995    2411700  2019     11   29
# 996    6218800  2019     12    2
# 997    4992800  2019     12    3
# 998    3512100  2019     12    4
# 999    4615500  2019     12    5
# 1000   4457800  2019     12    6
# 1001   5748400  2019     12    9
# 1002  10476100  2019     12   10
# 1003   5589800  2019     12   11
# 1004   4766600  2019     12   12
# 1005   3879700  2019     12   13
# 1006   4658900  2019     12   16

# %% [markdown]
# # Information About Our Dataset Like the Total Number of Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement¶

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1007 non-null   datetime64[ns]
#  1   Open       1007 non-null   float64
#  2   High       1007 non-null   float64
#  3   Low        1007 non-null   float64
#  4   Close      1007 non-null   float64
#  5   Adj Close  1007 non-null   float64
#  6   Volume     1007 non-null   int64
#  7   year       1007 non-null   int32
#  8   month      1007 non-null   int32
#  9   day        1007 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(3), int64(1)
# memory usage: 67.0 KB

# %% [markdown]
# # FINDING SHAPE OF DATASET

# %%
netflix.shape
# Out:
# (1007, 10)

# %% [markdown]
# # Get Overall Statistics About The Dataset

# %%
netflix.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1007  1007.000000  1007.000000  1007.000000
# mean   2017-12-16 11:16:23.118172672   226.708094   229.972979   223.105690
# min              2015-12-16 00:00:00    80.570000    84.699997    79.949997
# 25%              2016-12-14 12:00:00   125.779999   127.165001   124.355000
# 50%              2017-12-14 00:00:00   197.850006   199.440002   195.330002
# 75%              2018-12-15 12:00:00   325.529999   330.835006   318.869995
# max              2019-12-16 00:00:00   421.380005   423.209991   413.079987
# std                              NaN   103.305422   104.851349   101.458611
#
#              Close    Adj Close        Volume         year        month  \
# count  1007.000000  1007.000000  1.007000e+03  1007.000000  1007.000000
# mean    226.670159   226.670159  9.730586e+06  2017.457795     6.539225
# min      82.790001    82.790001  1.616300e+06  2015.000000     1.000000
# 25%     125.514999   125.514999  5.573200e+06  2016.000000     4.000000
# 50%     198.000000   198.000000  7.857600e+06  2017.000000     7.000000
# 75%     325.220001   325.220001  1.178630e+07  2018.000000    10.000000
# max     418.970001   418.970001  5.841040e+07  2019.000000    12.000000
# std     103.203785   103.203785  6.398967e+06     1.138499     3.421979
#
#                day
# count  1007.000000
# mean     15.750745
# min       1.000000
# 25%       8.000000
# 50%      16.000000
# 75%      23.000000
# max      31.000000
# std       8.749237

# %% [markdown]
# # FINDING ROWS AND COLUMNS

# %%
print("Number of Rows",netflix.shape[0])
print("Number of Columns",netflix.shape[1])
# Out:
# Number of Rows 1007
# Number of Columns 7

# %% [markdown]
# # Check Null Values In The Dataset

# %%
netflix.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# year         0
# month        0
# day          0
# dtype: int64

# %% [markdown]
# # DROPPING A COLUMN

# %%
netflix.drop('Date',axis=1,inplace=True)

# %%
netflix
# Out:
#             Open        High         Low       Close   Adj Close    Volume  \
# 0     119.800003  123.000000  118.089996  122.639999  122.639999  13181000
# 1     123.970001  126.349998  122.419998  122.510002  122.510002  17284900
# 2     120.849998  122.190002  117.919998  118.019997  118.019997  17948100
# 3     119.510002  119.589996  115.660004  116.629997  116.629997  11670000
# 4     117.300003  117.430000  114.860001  116.239998  116.239998   9689000
# ...          ...         ...         ...         ...         ...       ...
# 1002  296.119995  298.940002  292.019989  293.119995  293.119995  10476100
# 1003  294.489990  299.429993  294.200012  298.929993  298.929993   5589800
# 1004  295.670013  299.170013  295.059998  298.440002  298.440002   4766600
# 1005  298.500000  301.799988  297.250000  298.500000  298.500000   3879700
# 1006  300.850006  305.709991  298.630005  304.209991  304.209991   4658900
#
#       year  month  day
# 0     2015     12   16
# 1     2015     12   17
# 2     2015     12   18
# 3     2015     12   21
# 4     2015     12   22
# ...    ...    ...  ...
# 1002  2019     12   10
# 1003  2019     12   11
# 1004  2019     12   12
# 1005  2019     12   13
# 1006  2019     12   16
#
# [1007 rows x 9 columns]

# %% [markdown]
# # FINDING DUPLICATES IN DATASET

# %%
netflix.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = netflix.corr()

# %%
corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999489  0.999333  0.998712   0.998712 -0.095059
# High       0.999489  1.000000  0.999264  0.999438   0.999438 -0.084998
# Low        0.999333  0.999264  1.000000  0.999448   0.999448 -0.107404
# Close      0.998712  0.999438  0.999448  1.000000   1.000000 -0.095180
# Adj Close  0.998712  0.999438  0.999448  1.000000   1.000000 -0.095180
# Volume    -0.095059 -0.084998 -0.107404 -0.095180  -0.095180  1.000000
# year       0.899941  0.900026  0.901401  0.901240   0.901240 -0.170042
# month      0.006075  0.006194  0.004210  0.003696   0.003696 -0.180667
# day       -0.009335 -0.010130 -0.010698 -0.012382  -0.012382  0.047534
#
#                year     month       day
# Open       0.899941  0.006075 -0.009335
# High       0.900026  0.006194 -0.010130
# Low        0.901401  0.004210 -0.010698
# Close      0.901240  0.003696 -0.012382
# Adj Close  0.901240  0.003696 -0.012382
# Volume    -0.170042 -0.180667  0.047534
# year       1.000000 -0.061639 -0.032741
# month     -0.061639  1.000000  0.011034
# day       -0.032741  0.011034  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm',cbar=True)
# Out:
# <Axes: >

# %%
sns.pairplot(netflix)
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for i in netflix.columns:
 plt.figure(figsize=(10,6))
 sns.distplot(netflix[i])
 plt.title(i)
 plt.show()
# Out:
# C:\Users\91950\AppData\Local\Temp\ipykernel_14356\4051014174.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(netflix[i])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 for i in netflix.columns:
#       2  plt.figure(figsize=(10,6))
# ----> 3  sns.distplot(netflix[i])
#       4  plt.title(i)
#       5  plt.show()
#
# File ~\.anaconda\anaconda\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File ~\.anaconda\anaconda\Lib\site-packages\pandas\core\series.py:917, in Series.__array__(self, dtype)
#     870 """
#     871 Return the values as a NumPy array.
#     872
#    (...)
#     914       dtype='datetime64[ns]')
#     915 """
#     916 values = self._values
# --> 917 arr = np.asarray(values, dtype=dtype)
#     918 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     919     arr = arr.view()
#
# ValueError: could not convert string to float: '2015-12-16'

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
X = netflix.drop('Close',axis=1)

# %%
 y = netflix['Close']

# %%
X.shape
# Out:
# (1007, 6)

# %%
y.shape
# Out:
# (1007,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (805, 6)

# %%
X_test.shape
# Out:
# (202, 6)

# %%
X_train
# Out:
#            Date        Open        High         Low   Adj Close    Volume
# 687  2018-09-10  352.269989  352.500000  343.079987  348.410004   5752200
# 458  2017-10-11  195.570007  196.220001  193.809998  194.949997   6450200
# 922  2019-08-16  298.859985  303.549988  296.269989  302.799988   6905800
# 200  2016-10-03   98.000000  103.389999   98.000000  102.629997  15344500
# 437  2017-09-12  182.550003  185.330002  180.639999  185.149994   6689600
# ..          ...         ...         ...         ...         ...       ...
# 534  2018-01-31  281.940002  282.290009  269.579987  270.299988  11695100
# 584  2018-04-13  317.290009  317.489990  308.230011  311.649994  12046600
# 493  2017-11-30  190.309998  190.860001  186.679993  187.580002   6630100
# 527  2018-01-22  222.000000  227.789993  221.199997  227.580002  17703300
# 168  2016-08-17   94.940002   96.930000   94.849998   96.370003   8315600
#
# [805 rows x 6 columns]

# %%
y_train
# Out:
# 687    348.410004
# 458    194.949997
# 922    302.799988
# 200    102.629997
# 437    185.149994
#           ...
# 534    270.299988
# 584    311.649994
# 493    187.580002
# 527    227.580002
# 168     96.370003
# Name: Close, Length: 805, dtype: float64

# %% [markdown]
# # Normalizating Data Using StandarScaler

# %%
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()

# %%
X_train = sclr.fit_transform(X_train)
X_test = sclr.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14356\1356191888.py in ?()
# ----> 1 X_train = sclr.fit_transform(X_train)
#       2 X_test = sclr.transform(X_test)
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return_tuple = (
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     911         # non-optimized default implementation; override when a better
#     912         # method is possible for a given clustering algorithm
#     913         if y is None:
#     914             # fit method of arity 1 (unsupervised transformation)
# --> 915             return self.fit(X, **fit_params).transform(X)
#     916         else:
#     917             # fit method of arity 2 (supervised transformation)
#     918             return self.fit(X, y, **fit_params).transform(X)
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     833             Fitted scaler.
#     834         """
#     835         # Reset internal state before fitting
#     836         self._reset()
# --> 837         return self.partial_fit(X, y, sample_weight)
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     869         self : object
#     870             Fitted scaler.
#     871         """
#     872         first_call = not hasattr(self, "n_samples_seen_")
# --> 873         X = self._validate_data(
#     874             X,
#     875             accept_sparse=("csr", "csc"),
#     876             dtype=FLOAT_DTYPES,
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     600                 out = y
#     601             else:
#     602                 out = X, y
#     603         elif not no_val_X and no_val_y:
# --> 604             out = check_array(X, input_name="X", **check_params)
#     605         elif no_val_X and not no_val_y:
#     606             out = _check_y(y, **check_params)
#     607         else:
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# ~\.anaconda\anaconda\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~\.anaconda\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: '2018-09-10'

# %%
X_train
# Out:
#            Date        Open        High         Low   Adj Close    Volume
# 687  2018-09-10  352.269989  352.500000  343.079987  348.410004   5752200
# 458  2017-10-11  195.570007  196.220001  193.809998  194.949997   6450200
# 922  2019-08-16  298.859985  303.549988  296.269989  302.799988   6905800
# 200  2016-10-03   98.000000  103.389999   98.000000  102.629997  15344500
# 437  2017-09-12  182.550003  185.330002  180.639999  185.149994   6689600
# ..          ...         ...         ...         ...         ...       ...
# 534  2018-01-31  281.940002  282.290009  269.579987  270.299988  11695100
# 584  2018-04-13  317.290009  317.489990  308.230011  311.649994  12046600
# 493  2017-11-30  190.309998  190.860001  186.679993  187.580002   6630100
# 527  2018-01-22  222.000000  227.789993  221.199997  227.580002  17703300
# 168  2016-08-17   94.940002   96.930000   94.849998   96.370003   8315600
#
# [805 rows x 6 columns]

# %% [markdown]
# # K MEANS CLUSTERING

# %%
netflix.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
X = netflix[['High','Adj Close']]

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans()
k_means.fit(X)
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans()

# %% [markdown]
# # Elbow Method To Find Optimal Number of Clusters

# %%
wcss=[]
for i in range(1,11):
    k_means = KMeans(n_clusters=i)
    k_means.fit(X)
    wcss.append(k_means.inertia_)
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
wcss
# Out:
# [21774695.59254965,
#  2958392.0419097715,
#  1811830.9516675018,
#  729199.8554820153,
#  502813.87806065206,
#  329870.86737875,
#  255539.98966513592,
#  195784.79646616057,
#  152582.84161848604,
#  125599.88807653237]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(range(1,11),wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# # MODEL TRAINING

# %%
import pickle
pickle.dump(lr,open('model.pkl','wb'))

# %%
k_means = KMeans(n_clusters=5,random_state=42)
y_means = k_means.fit_predict(X)
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
y_means
# Out:
# array([4, 4, 2, ..., 3, 3, 3])

# %%
k_means.predict([[15,39]])
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2])

# %%
plt.scatter(X.iloc[y_means==0,0],X.iloc[y_means==0,1],s=100,c='red',label="Cluster 1")
plt.scatter(X.iloc[y_means==1,0],X.iloc[y_means==1,1],s=100,c='yellow',label="Cluster 2")
plt.scatter(X.iloc[y_means==2,0],X.iloc[y_means==2,1],s=100,c='green',label="Cluster 3")
plt.scatter(X.iloc[y_means==3,0],X.iloc[y_means==3,1],s=100,c='blue',label="Cluster 4")
plt.scatter(X.iloc[y_means==4,0],X.iloc[y_means==4,1],s=100,c='black',label="Cluster 5")
plt.scatter(k_means.cluster_centers_[:,0],k_means.cluster_centers_[:,1],s=100,c="magenta")
plt.title("NETFLIX PRICE")
plt.xlabel('High')
plt.ylabel("Low")
plt.legend()
plt.show()

# %% [markdown]
# # SAVE THE MODEL

# %%
import joblib

# %%
joblib.dump(k_means,"NTFX.csv")
# Out:
# ['NTFX.csv']

# %%
model = joblib.load("NTFX.csv")

# %%
model.predict([[15,39]])
# Out:
# C:\Users\91950\.anaconda\anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2])
